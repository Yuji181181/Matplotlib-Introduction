# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = ["A","B","C","D","E"]
y = [10,20,30,20,10]

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar(x,y,width = 0.5)
# Out:
# <BarContainer object of 5 artists>
