# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
A = [10,20,30,40]
B = ["a","b","c","d"]

# %%
plt.pie(x=A,labels=B,autopct="%.1f%%")
plt.legend()

# %%
colorlist=["r","b","g","k"]
plt.pie(x=A,labels=B,colors=colorlist)
# Out:
# ([<matplotlib.patches.Wedge at 0x2c68c72ea50>,
# ...
#  [Text(1.0461621663333946, 0.3399186987098808, 'a'),
#   Text(0.33991867422268784, 1.0461621742897658, 'b'),
#   Text(-1.0461621902025062, 0.3399186252483017, 'c'),
#   Text(0.3399188211458418, -1.0461621265515308, 'd')])
