# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
x = np.arange(10)
y = np.random.randint(-10,10,10)

# %%
y
# Out:
# array([ -9,  -9,  -5, -10,   3,  -9, -10,   3,  -7,  -2])

# %%
plt.plot(x,y)
