# %%
import matplotlib.pyplot as plt # type: ignore
# %matplotlib inline

# %%
x = [1, 2, 3, 4, 5]
y = [1, 4, 9, 16, 25]
plt.plot(x, y)
plt.xlabel('X')
plt.ylabel('Y')
plt.annotate("annotation",xy=(3,9),xytext=(1,20),fontsize=15,color="r",arrowprops=dict(color="k"))
plt.show()
