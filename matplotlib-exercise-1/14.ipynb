# %%
import matplotlib.pyplot as plt # type: ignore
# %matplotlib inline
import numpy as np # type: ignore

# %%
x = [1, 2, 3, 4, 5]
y = np.array([1, 4, 9, 16, 25])
plt.plot(x, y)
plt.plot(x,y/2)
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
